# %%
pip install secure-smtplib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import smtplib

# %%
conn=smtplib.SMTP('smtp.gmail.com',587)

# %%
type(conn)
# Out:
# smtplib.SMTP

# %%
conn.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [202.142.99.72]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
conn.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
conn.login('eea58514@gmail.com','9570808645')
# Out:
# (235, b'2.7.0 Accepted')

# %%
conn.sendmail('eea58514@gmail.com','ppa58514@gmail.com','Subject:sending an email using python\n\n Dear vikash \n\n Thanks for your video on this topic\n\n')
# Out:
# {}

# %%
conn.quit()
# Out:
# (221, b'2.0.0 closing connection r8sm18695471pjo.22 - gsmtp')

# %%
from IPython.display import Image

# %%
Image('email-provider.png')
